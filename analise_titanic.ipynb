# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:/Users/alexs/Downloads/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["age"] = df["age"].fillna(0)
df["age"] = df["age"].astype(int)

# %%
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   22      1      0   7.2500        S   Third
# 1           1       1  female   38      1      0  71.2833        C   First
# 2           1       3  female   26      0      0   7.9250        S   Third
# 3           1       1  female   35      1      0  53.1000        S   First
# 4           0       3    male   35      0      0   8.0500        S   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 886         0       2    male   27      0      0  13.0000        S  Second
# 887         1       1  female   19      0      0  30.0000        S   First
# 888         0       3  female    0      1      2  23.4500        S   Third
# 889         1       1    male   26      0      0  30.0000        C   First
# 890         0       3    male   32      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["deck"] = df["deck"].fillna("")
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   22      1      0   7.2500        S   Third
# 1           1       1  female   38      1      0  71.2833        C   First
# 2           1       3  female   26      0      0   7.9250        S   Third
# 3           1       1  female   35      1      0  53.1000        S   First
# 4           0       3    male   35      0      0   8.0500        S   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 886         0       2    male   27      0      0  13.0000        S  Second
# 887         1       1  female   19      0      0  30.0000        S   First
# 888         0       3  female    0      1      2  23.4500        S   Third
# 889         1       1    male   26      0      0  30.0000        C   First
# 890         0       3    male   32      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.rename(columns={"embark_town": "embark.town"}, inplace=True)
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   22      1      0   7.2500        S   Third
# 1           1       1  female   38      1      0  71.2833        C   First
# 2           1       3  female   26      0      0   7.9250        S   Third
# 3           1       1  female   35      1      0  53.1000        S   First
# 4           0       3    male   35      0      0   8.0500        S   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 886         0       2    male   27      0      0  13.0000        S  Second
# 887         1       1  female   19      0      0  30.0000        S   First
# 888         0       3  female    0      1      2  23.4500        S   Third
# 889         1       1    male   26      0      0  30.0000        C   First
# 890         0       3    male   32      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark.town alive  alone
# ...

# %%
ordernar_coluna = [
 'pclass', 'survived', 'sex', 'age', 'fare', 
    'embarked', 'embark.town', 'class', 'who', 
    'adult_male', 'deck', 'sibsp', 'parch', 'alive', 'alone'
]

df = df[ordernar_coluna]

# %%
df
# Out:
#      pclass  survived     sex  age     fare embarked  embark.town   class  \
# 0         3         0    male   22   7.2500        S  Southampton   Third
# 1         1         1  female   38  71.2833        C    Cherbourg   First
# 2         3         1  female   26   7.9250        S  Southampton   Third
# 3         1         1  female   35  53.1000        S  Southampton   First
# 4         3         0    male   35   8.0500        S  Southampton   Third
# ..      ...       ...     ...  ...      ...      ...          ...     ...
# 886       2         0    male   27  13.0000        S  Southampton  Second
# 887       1         1  female   19  30.0000        S  Southampton   First
# 888       3         0  female    0  23.4500        S  Southampton   Third
# 889       1         1    male   26  30.0000        C    Cherbourg   First
# 890       3         0    male   32   7.7500        Q   Queenstown   Third
#
#        who  adult_male deck  sibsp  parch alive  alone
# ...

# %%
excluir = ["alone", "parch" ]

def excluir_coluna (df, excluir):
    return df.drop(columns=excluir, errors="ignore", inplace=True)


result = excluir_coluna(df, excluir)
# Out:
# C:\Users\alexs\AppData\Local\Temp\ipykernel_19996\1328268267.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return df.drop(columns=excluir, errors="ignore", inplace=True)

# %%
df
# Out:
#      pclass  survived     sex  age     fare embarked  embark.town   class  \
# 0         3         0    male   22   7.2500        S  Southampton   Third
# 1         1         1  female   38  71.2833        C    Cherbourg   First
# 2         3         1  female   26   7.9250        S  Southampton   Third
# 3         1         1  female   35  53.1000        S  Southampton   First
# 4         3         0    male   35   8.0500        S  Southampton   Third
# ..      ...       ...     ...  ...      ...      ...          ...     ...
# 886       2         0    male   27  13.0000        S  Southampton  Second
# 887       1         1  female   19  30.0000        S  Southampton   First
# 888       3         0  female    0  23.4500        S  Southampton   Third
# 889       1         1    male   26  30.0000        C    Cherbourg   First
# 890       3         0    male   32   7.7500        Q   Queenstown   Third
#
#        who  adult_male deck  sibsp alive
# ...

# %%
df["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.loc[(df['class'] == "First") & (df["sex"] == "male")]
# Out:
#      pclass  survived   sex  age      fare embarked  embark.town  class  who  \
# 6         1         0  male   54   51.8625        S  Southampton  First  man
# 23        1         1  male   28   35.5000        S  Southampton  First  man
# 27        1         0  male   19  263.0000        S  Southampton  First  man
# 30        1         0  male   40   27.7208        C    Cherbourg  First  man
# 34        1         0  male   28   82.1708        C    Cherbourg  First  man
# ..      ...       ...   ...  ...       ...      ...          ...    ...  ...
# 839       1         1  male    0   29.7000        C    Cherbourg  First  man
# 857       1         1  male   51   26.5500        S  Southampton  First  man
# 867       1         0  male   31   50.4958        S  Southampton  First  man
# 872       1         0  male   33    5.0000        S  Southampton  First  man
# 889       1         1  male   26   30.0000        C    Cherbourg  First  man
#
#      adult_male deck  sibsp alive
# ...

# %%
sns.catplot(x="sex", hue="who", kind="count", data=df)
